# %% [markdown]
# * Import librairies

# %%
import os
import torch
from torch import nn
from torch.utils.data import DataLoader
import torchvision
from torchvision import transforms, models # import a library that contains pretrained models
from torchsummary import summary

# %% [markdown]
# * Download Multi-class Weather Dataset from kaggle

# %%
# !mkdir ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json
# !kaggle datasets download -d pratik2901/multiclass-weather-dataset
# !unzip 'multiclass-weather-dataset.zip'
# !kaggle datasets download -d pratik2901/multiclass-weather-dataset
# %cd "/content/Multi-class Weather Dataset"
# Out:
# cp: cannot stat 'kaggle.json': No such file or directory
# chmod: cannot access '/root/.kaggle/kaggle.json': No such file or directory
# Dataset URL: https://www.kaggle.com/datasets/pratik2901/multiclass-weather-dataset
# License(s): Attribution 4.0 International (CC BY 4.0)
# Downloading multiclass-weather-dataset.zip to /content
# 100% 91.0M/91.4M [00:05<00:00, 24.1MB/s]
# 100% 91.4M/91.4M [00:05<00:00, 18.8MB/s]
# Archive:  multiclass-weather-dataset.zip
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy1.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy10.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy100.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy101.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy102.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy103.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy104.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy105.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy106.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy107.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy108.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy109.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy11.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy110.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy111.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy112.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy113.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy114.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy115.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy116.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy117.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy118.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy119.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy12.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy120.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy121.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy122.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy123.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy124.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy125.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy126.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy127.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy128.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy129.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy13.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy130.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy131.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy132.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy133.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy134.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy135.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy136.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy137.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy138.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy139.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy14.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy140.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy141.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy142.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy143.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy144.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy145.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy146.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy147.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy148.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy149.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy15.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy150.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy151.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy152.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy153.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy154.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy155.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy156.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy157.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy158.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy159.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy16.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy160.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy161.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy162.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy163.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy164.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy165.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy166.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy167.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy168.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy169.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy17.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy170.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy171.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy172.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy173.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy174.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy175.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy176.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy177.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy178.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy179.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy18.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy180.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy181.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy182.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy183.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy184.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy185.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy186.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy187.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy188.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy189.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy19.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy190.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy191.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy192.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy193.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy194.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy195.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy196.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy197.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy198.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy199.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy2.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy20.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy200.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy201.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy202.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy203.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy204.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy205.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy206.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy207.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy208.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy209.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy21.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy210.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy211.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy212.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy213.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy214.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy215.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy216.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy217.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy218.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy219.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy22.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy220.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy221.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy222.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy223.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy224.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy225.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy226.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy227.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy228.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy229.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy23.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy230.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy231.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy232.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy233.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy234.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy235.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy236.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy237.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy238.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy239.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy24.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy240.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy241.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy242.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy243.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy244.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy245.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy246.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy247.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy248.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy249.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy25.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy250.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy251.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy252.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy253.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy254.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy255.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy256.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy257.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy258.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy259.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy26.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy260.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy261.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy262.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy263.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy264.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy265.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy266.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy267.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy268.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy269.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy27.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy270.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy271.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy272.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy273.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy274.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy275.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy276.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy277.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy278.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy279.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy28.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy280.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy281.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy282.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy283.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy284.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy285.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy286.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy287.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy288.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy289.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy29.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy290.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy291.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy292.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy293.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy294.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy295.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy296.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy297.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy298.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy299.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy3.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy30.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy300.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy31.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy32.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy33.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy34.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy35.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy36.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy37.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy38.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy39.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy4.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy40.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy41.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy42.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy43.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy44.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy45.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy46.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy47.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy48.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy49.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy5.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy50.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy51.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy52.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy53.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy54.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy55.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy56.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy57.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy58.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy59.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy6.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy60.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy61.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy62.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy63.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy64.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy65.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy66.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy67.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy68.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy69.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy7.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy70.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy71.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy72.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy73.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy74.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy75.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy76.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy77.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy78.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy79.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy8.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy80.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy81.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy82.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy83.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy84.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy85.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy86.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy87.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloudy88.jpg
#   inflating: Multi-class Weather Dataset/Cloudy/cloud
jpg
#   inflating: Multi-class Weather Dataset/Sunrise/sunrise69.jpg
#   inflating: Multi-class Weather Dataset/Sunrise/sunrise7.jpg
#   inflating: Multi-class Weather Dataset/Sunrise/sunrise70.jpg
#   inflating: Multi-class Weather Dataset/Sunrise/sunrise71.jpg
#   inflating: Multi-class Weather Dataset/Sunrise/sunrise72.jpg
#   inflating: Multi-class Weather Dataset/Sunrise/sunrise73.jpg
#   inflating: Multi-class Weather Dataset/Sunrise/sunrise74.jpg
#   inflating: Multi-class Weather Dataset/Sunrise/sunrise75.jpg
#   inflating: Multi-class Weather Dataset/Sunrise/sunrise76.jpg
#   inflating: Multi-class Weather Dataset/Sunrise/sunrise77.jpg
#   inflating: Multi-class Weather Dataset/Sunrise/sunrise78.jpg
#   inflating: Multi-class Weather Dataset/Sunrise/sunrise79.jpg
#   inflating: Multi-class Weather Dataset/Sunrise/sunrise8.jpg
#   inflating: Multi-class Weather Dataset/Sunrise/sunrise80.jpg
#   inflating: Multi-class Weather Dataset/Sunrise/sunrise81.jpg
#   inflating: Multi-class Weather Dataset/Sunrise/sunrise82.jpg
#   inflating: Multi-class Weather Dataset/Sunrise/sunrise83.jpg
#   inflating: Multi-class Weather Dataset/Sunrise/sunrise84.jpg
#   inflating: Multi-class Weather Dataset/Sunrise/sunrise85.jpg
#   inflating: Multi-class Weather Dataset/Sunrise/sunrise86.jpg
#   inflating: Multi-class Weather Dataset/Sunrise/sunrise87.jpg
#   inflating: Multi-class Weather Dataset/Sunrise/sunrise88.jpg
#   inflating: Multi-class Weather Dataset/Sunrise/sunrise89.jpeg
#   inflating: Multi-class Weather Dataset/Sunrise/sunrise9.jpg
#   inflating: Multi-class Weather Dataset/Sunrise/sunrise90.jpg
#   inflating: Multi-class Weather Dataset/Sunrise/sunrise91.jpg
#   inflating: Multi-class Weather Dataset/Sunrise/sunrise92.jpg
#   inflating: Multi-class Weather Dataset/Sunrise/sunrise93.jpg
#   inflating: Multi-class Weather Dataset/Sunrise/sunrise94.jpg
#   inflating: Multi-class Weather Dataset/Sunrise/sunrise95.jpg
#   inflating: Multi-class Weather Dataset/Sunrise/sunrise96.jpg
#   inflating: Multi-class Weather Dataset/Sunrise/sunrise97.jpg
#   inflating: Multi-class Weather Dataset/Sunrise/sunrise98.jpg
#   inflating: Multi-class Weather Dataset/Sunrise/sunrise99.jpg
# Dataset URL: https://www.kaggle.com/datasets/pratik2901/multiclass-weather-dataset
# License(s): Attribution 4.0 International (CC BY 4.0)
# multiclass-weather-dataset.zip: Skipping, found more recently modified local copy (use --force to force download)
# /content/Multi-class Weather Dataset

# %% [markdown]
# * Load all images from dataset

# %%
dataset = torchvision.datasets.ImageFolder(
        root = "/content/Multi-class Weather Dataset", # data_path is path to directory
        transform = None,
)

print(dataset)
# Out:
# Dataset ImageFolder
#     Number of datapoints: 1125
#     Root location: /content/Multi-class Weather Dataset

# %% [markdown]
# * Divide dataset into train (70%) and test (30%) subsets

# %%
train_size = int(0.7 * len(dataset))
test_size = len(dataset) - train_size
train_dataset, test_dataset = torch.utils.data.random_split(dataset, [train_size, test_size])

print(len(train_dataset), "train samples and", len(test_dataset), "test samples")
# Out:
# 787 train samples and 338 test samples

# %% [markdown]
# * Define transformations on train and tests subsets

# %%
IMAGE_SIZE = 128

train_transform = transforms.Compose(
    [
        transforms.Resize((IMAGE_SIZE,IMAGE_SIZE)),
        transforms.RandomRotation(10),
        transforms.RandomResizedCrop(64),
        transforms.RandomHorizontalFlip(),
        transforms.ToTensor(),
    ]
)

test_transform = transforms.Compose(
    [
        transforms.Resize((IMAGE_SIZE,IMAGE_SIZE)),
        transforms.ToTensor(),
    ]
)

train_dataset.dataset.transform = train_transform
test_dataset.dataset.transform = test_transform

# %% [markdown]
# * Create DataLoader object for train and test subsets

# %%
train_loader = torch.utils.data.DataLoader(dataset = train_dataset,
                                           batch_size = 32,
                                           shuffle = True
)

test_loader = torch.utils.data.DataLoader(dataset = test_dataset,
                                          batch_size = 32,
                                          shuffle = False
)

for batch_num, (images, targets) in enumerate(train_loader):
  print("Batch image size", images.shape, "---- Batch label size", targets.shape)
# Out:
# Batch image size torch.Size([32, 3, 128, 128]) ---- Batch label size torch.Size([32])
# Batch image size torch.Size([32, 3, 128, 128]) ---- Batch label size torch.Size([32])
# Batch image size torch.Size([32, 3, 128, 128]) ---- Batch label size torch.Size([32])
# Batch image size torch.Size([32, 3, 128, 128]) ---- Batch label size torch.Size([32])
# Batch image size torch.Size([32, 3, 128, 128]) ---- Batch label size torch.Size([32])
# Batch image size torch.Size([32, 3, 128, 128]) ---- Batch label size torch.Size([32])
# Batch image size torch.Size([32, 3, 128, 128]) ---- Batch label size torch.Size([32])
# Batch image size torch.Size([32, 3, 128, 128]) ---- Batch label size torch.Size([32])
# Batch image size torch.Size([32, 3, 128, 128]) ---- Batch label size torch.Size([32])
# Batch image size torch.Size([32, 3, 128, 128]) ---- Batch label size torch.Size([32])
# Batch image size torch.Size([32, 3, 128, 128]) ---- Batch label size torch.Size([32])
# Batch image size torch.Size([32, 3, 128, 128]) ---- Batch label size torch.Size([32])
# Batch image size torch.Size([32, 3, 128, 128]) ---- Batch label size torch.Size([32])
# Batch image size torch.Size([32, 3, 128, 128]) ---- Batch label size torch.Size([32])
# Batch image size torch.Size([32, 3, 128, 128]) ---- Batch label size torch.Size([32])
# Batch image size torch.Size([32, 3, 128, 128]) ---- Batch label size torch.Size([32])
# Batch image size torch.Size([32, 3, 128, 128]) ---- Batch label size torch.Size([32])
# Batch image size torch.Size([32, 3, 128, 128]) ---- Batch label size torch.Size([32])
# Batch image size torch.Size([32, 3, 128, 128]) ---- Batch label size torch.Size([32])
# Batch image size torch.Size([32, 3, 128, 128]) ---- Batch label size torch.Size([32])
# Batch image size torch.Size([32, 3, 128, 128]) ---- Batch label size torch.Size([32])
# Batch image size torch.Size([32, 3, 128, 128]) ---- Batch label size torch.Size([32])
# Batch image size torch.Size([32, 3, 128, 128]) ---- Batch label size torch.Size([32])
# Batch image size torch.Size([32, 3, 128, 128]) ---- Batch label size torch.Size([32])
# Batch image size torch.Size([19, 3, 128, 128]) ---- Batch label size torch.Size([19])

# %% [markdown]
# * Load the pretrained VGG16 model and turn it to CUDA device if available

# %%
vgg = models.vgg16(pretrained= True) # import vgg16 model

if torch.cuda.is_available():
  device = "cuda"
else:
  device = "cpu"

vgg = vgg.to(device)

print(vgg)
# Out:
# VGG(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(inplace=True)
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): ReLU(inplace=True)
#     (7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): ReLU(inplace=True)
#     (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace=True)
#     (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (13): ReLU(inplace=True)
#     (14): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (15): ReLU(inplace=True)
#     (16): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (17): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (18): ReLU(inplace=True)
#     (19): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (20): ReLU(inplace=True)
#     (21): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (22): ReLU(inplace=True)
#     (23): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (24): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (25): ReLU(inplace=True)
#     (26): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (27): ReLU(inplace=True)
#     (28): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (29): ReLU(inplace=True)
#     (30): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(7, 7))
#   (classifier): Sequential(
#     (0): Linear(in_features=25088, out_features=4096, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Dropout(p=0.5, inplace=False)
#     (3): Linear(in_features=4096, out_features=4096, bias=True)
#     (4): ReLU(inplace=True)
#     (5): Dropout(p=0.5, inplace=False)
#     (6): Linear(in_features=4096, out_features=1000, bias=True)
#   )
# )

# %% [markdown]
# ### Adapt VGG16 to our downstream task (modify classification part)

# %% [markdown]
# * Set the input size of vgg as (3, 128, 128)
# * Set the configuration of the classifier part as follow:
#   - hidden layer of 512 neurons with ReLU
#   - hidden layer of 4 neurons with SoftMax

# %%
# set the vgg input size as (3, 128, 128)
vgg.input_size = (3, 128, 128)

# change the classifier part of vgg
vgg.classifier = nn.Sequential(
    nn.Linear(in_features=25088, out_features= 512 ),
    nn.ReLU(),
    nn.Linear(in_features= 512 , out_features=4),
    nn.Softmax(dim=1),
)

print(vgg)
# Out:
# VGG(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(inplace=True)
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): ReLU(inplace=True)
#     (7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): ReLU(inplace=True)
#     (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace=True)
#     (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (13): ReLU(inplace=True)
#     (14): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (15): ReLU(inplace=True)
#     (16): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (17): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (18): ReLU(inplace=True)
#     (19): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (20): ReLU(inplace=True)
#     (21): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (22): ReLU(inplace=True)
#     (23): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (24): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (25): ReLU(inplace=True)
#     (26): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (27): ReLU(inplace=True)
#     (28): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (29): ReLU(inplace=True)
#     (30): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(7, 7))
#   (classifier): Sequential(
#     (0): Linear(in_features=25088, out_features=512, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=512, out_features=4, bias=True)
#     (3): Softmax(dim=1)
#   )
# )

# %% [markdown]
# * Set the features layer weights no-trainable

# %%
for param in vgg.features.parameters():
  param.requires_grad = False

# %% [markdown]
# * Define hyper-parameters (Loss function and optimizer)

# %%
# Loss function
loss_function = nn.CrossEntropyLoss()

# optimizer Adam
optimizer = torch.optim.Adam(params = vgg.parameters(), lr=1e-4)

# %% [markdown]
# * Run the training Loop

# %%
# !export CUDA_LAUNCH_BLOCKING=1

epochs = 20

# turn vgg model to CUDA device (after being finetuned)
vgg.to(device)

# set the model to train mode
vgg.train()


for epoch in range(epochs):

    # define a list to store the losses of the different batches
    losses = []

    # iter over patches
    for batch_num, (train_images, train_targets) in enumerate(train_loader):

        # initialize the optimizer (Zero the gradients)
        optimizer.zero_grad()

        # extract images and targets from input_data (Get inputs)
        train_images = train_images.to(device)
        train_targets = train_targets.to(device)

        # Propagate the images and return the predicted output (Perform forward pass)
        outputs = vgg(train_images)

        # calculate the loss between actual and predicted outputs (Compute loss)
        loss = loss_function(outputs, train_targets)
        losses.append(loss.item())

        # Prpagate the gradient of the loss in reverse (Perform backward pass)
        loss.backward()

        # update the model parameters (Perform optimization)
        optimizer.step()

    print('Epoch %d -- Loss %6.4f' % (epoch, sum(losses)/len(losses)))

# Process is complete.
print('Training process has finished.')
# Out:
# Epoch 0 -- Loss 0.9756
# Epoch 1 -- Loss 0.8013
# Epoch 2 -- Loss 0.7715
# Epoch 3 -- Loss 0.7615
# Epoch 4 -- Loss 0.7569
# Epoch 5 -- Loss 0.7540
# Epoch 6 -- Loss 0.7510
# Epoch 7 -- Loss 0.7506
# Epoch 8 -- Loss 0.7502
# Epoch 9 -- Loss 0.7500
# Epoch 10 -- Loss 0.7497
# Epoch 11 -- Loss 0.7504
# Epoch 12 -- Loss 0.7494
# Epoch 13 -- Loss 0.7493
# Epoch 14 -- Loss 0.7492
# Epoch 15 -- Loss 0.7500
# Epoch 16 -- Loss 0.7490
# Epoch 17 -- Loss 0.7489
# Epoch 18 -- Loss 0.7482
# Epoch 19 -- Loss 0.7480
# Training process has finished.

# %% [markdown]
# * Save the trained model

# %%
torch.save(vgg, 'vgg.pth')

# %% [markdown]
# * Load the model and run evaluation

# %%
# load model saved in "vgg16_model.pth"
vgg16_model =torch.load('vgg.pth')

# turn the pretrained model to cuda device
if torch.cuda.is_available():
  device = "cuda"
else:
  device = "cpu"

vgg16_model = vgg16_model.to(device)

# initialize evaluation metrics
total_samples = len(test_loader.dataset)
correct_samples = 0
total_loss = 0

# set the model in evaluation mode
vgg16_model.eval()

# iter over batches
for num_batch, (test_images, test_targets) in enumerate(test_loader):

  # extract images and targets from test_data (Get inputs)
  test_images = test_images.to(device)
  test_targets = test_targets.to(device)

  # calculate logits
  outputs = vgg16_model(test_images)

  # calculate loss
  loss = loss_function(outputs, test_targets)
  total_loss += loss.item()

  # predict classes from outputs
  pred_targets = outputs.argmax(dim=1)

  # calculate correct predictions
  nb_correct = pred_targets.eq(test_targets).sum()
  correct_samples += nb_correct

avg_loss = total_loss / total_samples
val_accuracy = (correct_samples / total_samples)

print('\nAverage test loss: ' + '{:.4f}'.format(avg_loss) +
          '  val_accuracy:' + '{:.4f}'.format(val_accuracy) + '\n')
# Out:
# <ipython-input-46-da5cb34ed090>:2: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   vgg16_model =torch.load('vgg.pth')
# Average test loss: 0.0255  val_accuracy:0.9645
